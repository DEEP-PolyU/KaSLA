# %%
db_path = "./data/sft_data_collections/bird/dev/dev_databases/california_schools/california_schools.sqlite"

db_path = db_path.replace("./data/sft_data_collections/", "/home/chen/data/zheng/datasets_SQL/")
print(db_path)
# Out:
# /home/chen/data/zheng/datasets_SQL/bird/dev/dev_databases/california_schools/california_schools.sqlite
